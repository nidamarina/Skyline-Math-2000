# %% [markdown]
# <a href="https://colab.research.google.com/github/nidamarina/Skyline-Math-2000/blob/main/Notebook_1_Setup_by_Nida_Currier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Research Question: Is there an association between religion and condom usage? :

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url='https://drive.google.com/file/d/1IbHzUMYKFBkmW3TIvryP7XJlW-WkmGEw/view?usp=sharing'
path= 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
df = pd.read_csv(path)
df.head()
# Out:
#        AID  BIO_SEX        agew1 IMONTH4 IDAY4 IYEAR4   MACNO4 INTID4  \
# 0  5710027        2
# 1  5710131        2  19.42739726       5     6   2008  2288160    160
# 2  5710317        1
# 3  5710386        1  20.43013699       5    22   2008  2288238    238
# 4  5710455        2
#
#   BIO_SEX4 VERSION4  ... H4EO5C H4EO5D H4EO5E H4EO5F H4EO5G H4EO5H H4EO5I  \
# 0                    ...
# 1        2     V5.4  ...      0      0      0      0      0      0      0
# 2                    ...
# 3        1     V5.4  ...      0      0      0      0      0      0      0
# 4                    ...
#
#   H4EO5J H4EO6 H4EO7
# 0
# 1      0     2     1
# 2
# 3      0     4     1
# 4
#
# [5 rows x 976 columns]

# %% [markdown]
# Codebook 1:
# ![Screenshot 2023-04-27 at 11.57.22 AM.png](data:image/png;base64,...)

# %%
#Manage data for variable 1
df['Religion'] = df['H4RE1']
df['Religion'].value_counts()
# Out:
# 2     1675
#       1390
# 4     1128
# 1      962
# 3      925
# 9      330
# 5       34
# 6       24
# 8       14
# 96      11
# 98       7
# 7        4
# Name: Religion, dtype: int64

# %%
df['Religion'] = df['Religion'].loc[df['Religion'] !='96']
df['Religion'] = df['Religion'].loc[df['Religion'] !='98']
df['Religion'] = df['Religion'].loc[df['Religion'] !=' ']
df['Religion'].value_counts()
# Out:
# 2    1675
# 4    1128
# 1     962
# 3     925
# 9     330
# 5      34
# 6      24
# 8      14
# 7       4
# Name: Religion, dtype: int64

# %%
df['Religion'].replace(['1', '2', '3', '4', '5', '6', '7', '8', '9'] , ['Not_Religious' , 'Protestant', 'Catholic', 'Other_Christian' , 'Jewish' , 'Buddhist' , 'Hindu' , 'Muslim' , 'Other'] , inplace = True)
df['Religion'].value_counts()
# Out:
# Protestant         1675
# Other_Christian    1128
# Not_Religious       962
# Catholic            925
# Other               330
# Jewish               34
# Buddhist             24
# Muslim               14
# Hindu                 4
# Name: Religion, dtype: int64

# %%
#Graphs and tables or statistics

# %%
pip install researchPy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import researchpy as rp

# %%
rp.summary_cat(df['Religion'])
# Out:
#    Variable          Outcome  Count  Percent
# 0  Religion       Protestant   1675    32.87
# 1            Other_Christian   1128    22.14
# 2              Not_Religious    962    18.88
# 3                   Catholic    925    18.15
# 4                      Other    330     6.48
# 5                     Jewish     34     0.67
# 6                   Buddhist     24     0.47
# 7                     Muslim     14     0.27
# 8                      Hindu      4     0.08

# %%
import matplotlib

# %%
plt.figure(figsize=(10,10))
plt.title("What is your current religion?")
df['Religion'].value_counts().plot(kind ='pie', autopct='%1.1f%%')
# Out:
# <Axes: title={'center': 'What is your current religion?'}, ylabel='Religion'>

# %%
plt.xlabel("Percent")
plt.ylabel("Religion")
plt.title("What is your current religion?")
df['Religion'].value_counts(normalize = True).plot(kind ='barh', color = 'dodgerblue', width = 0.2, alpha = 0.5, grid = True)
# Out:
# <Axes: title={'center': 'What is your current religion?'}, ylabel='Religion'>

# %% [markdown]
# Codebook 2:![Screenshot 2023-04-30 at 11.02.19 AM.png](data:image/png;base64,...)

# %%
#Manage data for variable 2
df['Condom_Usage'] = df['H4SE26A']
df['Condom_Usage'].value_counts()
# Out:
# 1    2355
# 0    2007
#      1400
# 7     729
# 8       7
# 6       6
# Name: Condom_Usage, dtype: int64

# %%
df['Condom_Usage'] = df['Condom_Usage'].loc[df['Condom_Usage'] !='7']
df['Condom_Usage'] = df['Condom_Usage'].loc[df['Condom_Usage'] !='6']
df['Condom_Usage'] = df['Condom_Usage'].loc[df['Condom_Usage'] !='8']
df['Condom_Usage'] = df['Condom_Usage'].loc[df['Condom_Usage'] !=' ']
df['Condom_Usage'].value_counts()
# Out:
# 1    2355
# 0    2007
# Name: Condom_Usage, dtype: int64

# %%
df['Condom_Usage'].replace(['0', '1'] , ['NO' , 'Yes'] , inplace = True)
df['Condom_Usage'].value_counts()
# Out:
# Yes    2355
# NO     2007
# Name: Condom_Usage, dtype: int64

# %%
#Graphs and tables or statistics

# %%
rp.summary_cat(df['Condom_Usage'])
# Out:
#        Variable Outcome  Count  Percent
# 0  Condom_Usage     Yes   2355    53.99
# 1                    NO   2007    46.01

# %%
plt.title("Have you had sex with a condom in the last 12 months?")
df['Condom_Usage'].value_counts().plot(kind ='pie', autopct='%1.1f%%', colors=['plum', 'orchid'])
# Out:
# <Axes: title={'center': 'Have you had sex with a condom in the last 12 months?'}, ylabel='Condom_Usage'>

# %%
plt.xlabel("Used A Condom")
plt.ylabel("Percent")
plt.title("Have you had sex with a condom in the last 12 months?")
df['Condom_Usage'].value_counts(normalize = True).plot(kind ='bar', color = 'mediumorchid', width = 0.2, alpha = 0.5)
# Out:
# <Axes: title={'center': 'Have you had sex with a condom in the last 12 months?'}, xlabel='Used A Condom', ylabel='Percent'>
